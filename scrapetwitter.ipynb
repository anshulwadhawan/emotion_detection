# %%
pip install twitterscraper
# Out:
# ...
#      |████████████████████████████████| 92kB 3.0MB/s
# ...
#   Created wheel for twitterscraper: filename=twitterscraper-1.4.0-cp36-none-any.whl size=11347 sha256=38a73c611f65ac4d6c42361ba6edd5d2812e77790bd70ecd9511efe926e60b77
#   Stored in directory: /root/.cache/pip/wheels/c2/9c/8b/7393e7bdc8abe6ce0d46c2ffae2035a1a2080a97ff0ddbdde6
# Successfully built twitterscraper
# ...

# %%
pip install langdetect
# Out:
# ...
#      |████████████████████████████████| 983kB 2.8MB/s
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.8-cp36-none-any.whl size=993193 sha256=71a55492c8735d12fb4cc9f906ee849c226656052b40653b346afb0e58d15b03
#   Stored in directory: /root/.cache/pip/wheels/8d/b3/aa/6d99de9f3841d7d3d40a60ea06e6d669e8e5012e6c8b947a57
# Successfully built langdetect
# ...

# %%
#https://twitter.com/search?q=(%23sarcasm)%20lang%3Ahi&src=typed_query&f=live
import twitterscraper
from twitterscraper import query_tweets
from langdetect import detect

# All tweets matching either Trump or Clinton will be returned. You will get at
# least 10 results within the minimal possible time/number of requests
file = open('output.txt','w')
count = 0
for tweet in query_tweets("(#sad) lang:hi", 50000):
    if(tweet.text==''):
      continue
    lang = detect(tweet.text)
    if(lang=="hi" or lang=="mr"):
      continue
    maxchar = max(tweet.text)
    if maxchar > u'\u007f':
      continue
    mystring=tweet.text
    mystring = mystring.replace('\n', ' ').replace('\r', '')
    file.write(tweet.tweet_id+'\n')
    file.write(mystring +'\n') 
    file.write('\n')
    count=count+1
    #print(lang)
    #print(tweet.text)
    #print(tweet.tweet_id)

print(count)
file.close()
from google.colab import files
files.download('output.txt')
#import codecs,json
#twitterscraper --limit 100 --output=tweets.json
#with codecs.open('tweets.json','r','utf-8') as f:
#  tweets=json.load(f,encoding='utf-8')

#print(tweets)
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (Windows NT 5.2; RW; rv:7.0a1) Gecko/20091211 SeaMonkey/9.23a1pre'}
# ...

# %%
from google.colab import files
files.download('output.txt')
